# %%
import json

file_path = "output/test.jsonl"
samples = []
with open("output/samples.jsonl", "r", encoding="utf-8") as file:
    for i,line in enumerate(file):
        data = json.loads(line)
        samples.append(data)

# %%
len(samples)
# Out:
# 29

# %%
samples[0]
# Out:
# {'question': '周围性神经炎能治好吗？',
#  'similar_question': ['周围性神经炎有望治愈吗？',
#   '周围性神经炎的治疗前景如何？',
#   '是否存在治愈周围性神经炎的可能性？',
#   '周围性神经炎能否完全康复？',
#   '对于周围性神经炎，我们有治愈的希望吗？',
#   '周围性神经炎的治愈概率有多大？',
#   '周围性神经炎是否可以被彻底治好？',
#   '在治疗周围性神经炎方面，我们能期待完全康复吗？',
#   '周围性神经炎的治愈过程，是否意味着可以完全恢复？',
#   '关于周围性神经炎，治疗后能否达到完全康复的状态？'],
#  'answer': '多发性神经炎多为功能性神经损害，治疗恢复在于及早的对受累神经进行充分的血供营养，同时兴奋激活神经，营养神经才能使恢复神经功能获得早日康复。提示，一但迟发缺血性神经变性病变。恢复无望而且病情还会加重。需指导请发病检资料为你指导。。。。目前比较科学的治疗方法是神经组织修复疗法，安全性好。与传统治疗相比，""神经组织修复疗法""治疗具有安全、无明显毒副作用的优点。'}

# %%
samples[0]["similar_question"]
# Out:
# ['周围性神经炎有望治愈吗？',
#  '周围性神经炎的治疗前景如何？',
#  '是否存在治愈周围性神经炎的可能性？',
#  '周围性神经炎能否完全康复？',
#  '对于周围性神经炎，我们有治愈的希望吗？',
#  '周围性神经炎的治愈概率有多大？',
#  '周围性神经炎是否可以被彻底治好？',
#  '在治疗周围性神经炎方面，我们能期待完全康复吗？',
#  '周围性神经炎的治愈过程，是否意味着可以完全恢复？',
#  '关于周围性神经炎，治疗后能否达到完全康复的状态？']

# %%
samples[0]["similar_question"][0]
# Out:
# '周围性神经炎有望治愈吗？'

# %%
with open(file_path, "w", encoding="utf-8") as file:
    for sample in samples:
        # 将字典转换为JSON格式的字符串
        json_str = json.dumps(sample, ensure_ascii=False)
        file.write(json_str + "\n")
